# %% [markdown]
# <a href="https://colab.research.google.com/github/kingspy89/ml_learnings-/blob/main/end_to_end_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 80   4.9  196.0
# 52   7.0  175.0
# 12   5.4  139.0
# 50   3.5  233.0
# 69   8.5  120.0
# ..   ...    ...
# 14   6.1  103.0
# 81   5.4  107.0
# 60   6.9  139.0
# 82   6.5   37.0
# 59   4.8  112.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 80    0
# 52    1
# 12    0
# 50    0
# 69    1
#      ..
# 14    0
# 81    0
# 60    1
# 82    1
# 59    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 67   5.0  118.0
# 53   8.3  168.0
# 29   7.0  112.0
# 55   7.8  114.0
# 92   5.2  110.0
# 65   8.1  166.0
# 27   6.0  124.0
# 39   4.6  146.0
# 51   4.8  141.0
# 93   6.8  112.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.95129702,  1.77821321],
#        [ 0.95129702,  1.26845696],
#        [-0.49829844,  0.3945891 ],
#        [-2.21969305,  2.67635518],
#        [ 2.31029277, -0.06661894],
#        [-1.49489532,  1.87530964],
#        [-1.13249646, -1.71725823],
#        [ 1.22309617, -0.16371537],
#        [ 0.58889816, -0.06661894],
#        [-0.49829844,  0.29749267],
#        [ 1.22309617,  0.34604088],
#        [-0.13589957,  0.46741142],
#        [ 0.86069731,  0.37031499],
#        [-0.22649929,  0.41886321],
#        [ 0.31709901,  0.12757392],
#        [ 0.31709901,  0.10329981],
#        [-2.40089249,  1.46264982],
#        [ 0.04529986, -1.88717698],
#        [-1.04189674,  1.12281232],
#        [-0.67949787,  0.22467035],
#        [ 1.04189674, -1.81435466],
#        [ 0.49829844,  0.17612213],
#        [-0.58889816, -0.21226358],
#        [ 1.22309617, -1.76580645],
#        [-0.77009759,  0.12757392],
#        [-0.95129702, -0.06661894],
#        [ 0.22649929, -0.23653769],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.86069731, -0.11516715],
#        [ 2.12909334,  1.09853821],
#        [ 0.95129702, -0.2608118 ],
#        [ 1.67609476, -0.21226358],
#        [-0.67949787, -0.30936001],
#        [ 1.94789391,  1.04998999],
#        [ 0.04529986,  0.03047749],
#        [-1.22309617,  0.56450785],
#        [-1.04189674,  0.44313731],
#        [ 0.77009759, -0.2608118 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 67    0
# 53    1
# 29    1
# 55    1
# 92    0
# 65    1
# 27    1
# 39    0
# 51    0
# 93    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %% [markdown]
# #api data fetching day 17

# %%
import pandas as pd
import requests

# %%
res=requests.get("https://api.apify.com/v2/datasets/lW34ui6mzeLOXnnlz/items?token=yourtoken")

# %%
res.json()
# Out:
# [{'title': 'AI Company India',
#   'price': None,
#   'categoryName': 'Software company',
#   'address': '1st Floor, 442, 14th Cross Rd, Tigalarpalya, Brookefield, Bengaluru, Karnataka 560066, India',
#   'neighborhood': 'Tigalarpalya, Brookefield',
#   'street': '1st Floor, 442, 14th Cross Rd',
#   'city': 'Bengaluru',
#   'postalCode': '560066',
#   'state': 'Karnataka',
#   'countryCode': 'IN',
#   'website': 'https://aicompanyindia.com/',
#   'phone': '+91 97172 41805',
#   'phoneUnformatted': '+919717241805',
#   'claimThisBusiness': False,
#   'location': {'lat': 12.9573579, 'lng': 77.72042},
#   'totalScore': 5,
#   'permanentlyClosed': False,
#   'temporarilyClosed': False,
#   'placeId': 'ChIJ3RXePtUTrjsRcaGrHaXaeaE',
#   'categories': ['Software company'],
#   'fid': '0x3bae13d53ede15dd:0xa179daa51daba171',
#   'cid': '11635571514990633329',
#   'reviewsCount': 3,
#   'imagesCount': 2,
#   'imageCategories': [],
#   'scrapedAt': '2026-01-29T08:37:02.902Z',
# ...

# %%
df =pd.DataFrame(res.json())[['title','categoryName','city','website']]

# %%
df.head()
# Out:
#                      title      categoryName       city  \
# 0         AI Company India  Software company  Bengaluru
# 1          AI Software LLC  Software company  Ahmedabad
# 2              TECH AI INC  Software company  Bengaluru
# 3     Indian AI Production  Software company  Hyderabad
# 4  AI Lead Vision Pvt. Ltd  Software company  Bengaluru
#
#                               website
# 0         https://aicompanyindia.com/
# 1      https://www.aisoftwarellc.com/
# 2          https://www.techaiinc.com/
# 3  http://www.indianaiproduction.com/
# 4            http://aileadvision.com/

# %%
df.to_csv("ai_company_webscreaped.csv")

# %% [markdown]
# # webscreaping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %%
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2435106094.py in <cell line: 0>()
# ----> 1 webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
soup.find_all('h1')[0].text
# Out:
# 'Access Denied'
