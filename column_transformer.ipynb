# %% [markdown]
# <a href="https://colab.research.google.com/github/kingspy89/ml_learnings-/blob/main/column_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
df= pd.read_csv('covid_toy.csv')

# %%
from sklearn.compose import ColumnTransformer
transformer = ColumnTransformer(transformers=[('tnf1',SimpleImputer(),['fever'])
                                ,('tnf2',OrdinalEncoder(categories=[['Mild','Strong']])),['cough']
                                ,('tnf3',OneHotEncoder(sparse=Fasle,drop='first',['gender','city']))]
                                ,remainder='passthrough')
# Out:
#   File "/tmp/ipython-input-4197573226.py", line 4
#     ,('tnf3',OneHotEncoder(sparse=Fasle,drop='first',['gender','city']))]
#                                                                       ^
# SyntaxError: positional argument follows keyword argument
